# %%
import datetime
import glob
import pandas as pd

# %%
def load_data(date=None, date_from=None, date_to=None):

    data_list = glob.glob('../rawdata/*-tripdata.csv.zip')
    data_list.sort()
    def read_csv(filename):
        return pd.read_csv(filename, compression='zip')
    
    if date is not None:
        filename = '../rawdata/{}-tripdata.csv.zip'.format(date)
        return read_csv(filename)
        
    if date is None and date_from is None and date_to is None:
        return read_csv(data_list[0])

# %%
load_data()
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0                 680  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1                1282  2017-01-01 00:00:45  2017-01-01 00:22:08
# 2                 648  2017-01-01 00:00:57  2017-01-01 00:11:46
# 3                 631  2017-01-01 00:01:10  2017-01-01 00:11:42
# 4                 621  2017-01-01 00:01:25  2017-01-01 00:11:47
# ...               ...                  ...                  ...
# 726671            340  2017-01-31 23:59:14  2017-02-01 00:04:55
# 726672            338  2017-01-31 23:59:23  2017-02-01 00:05:01
# 726673             79  2017-01-27 04:59:49  2017-01-27 05:01:08
# 726674            711  2017-01-27 06:23:29  2017-01-27 06:35:21
# 726675            623  2017-01-27 06:36:39  2017-01-27 06:47:02
#
#         Start Station ID           Start Station Name  Start Station Latitude  \
# 0                   3226  W 82 St & Central Park West               40.782750
# ...
